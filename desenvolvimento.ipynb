# %%
import bovespa
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import re
import logging
import matplotlib. pyplot as plt

# %%
# Coloque o nome das acoes e incial das opcoes aqui
papel_acao = 'PETR4'
papel_opcoes = ['PETRF', 'PETRE']

tabela_vencimento_opcao =  {'A':datetime(2020,1,20), 'B':datetime(2020,2,17), 'C':datetime(2020,3,16),
                        'D':datetime(2020,4,20), 'E':datetime(2020,5,18), 'F':datetime(2020,6,15),
                        'G':datetime(2020,7,20), 'H':datetime(2020,8,17), 'I':datetime(2020,9,21),
                        'J':datetime(2020,10,19), 'K':datetime(2020,11,16), 'L':datetime(2020,12,21),
                            }

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
ontem = datetime.today() - timedelta(days=1)
hoje = datetime.today()

data_negociacao = hoje

acao = bovespa.get_values(papel_acao)
opcao = bovespa.get_values(papel_opcoes, exact=False)

# %%
aval_opcoes = bovespa.process(acao, opcao, tabela_vencimento_opcao, filter_date = data_negociacao)
opcoes_ordenadas_lucro = aval_opcoes.sort_values('lucro aa', ascending=False)
display(opcoes_ordenadas_lucro[:10])
# Out:
#                       acao tipo acao  valor acao                    opcao  \
# 24   PETR4 PETROBRAS PN N2        PN       17.75   PETRE177 PETR PN 17,72
# 161  PETR4 PETROBRAS PN N2        PN       17.75   PETRE49 PETRE PN 17,97
# 23   PETR4 PETROBRAS PN N2        PN       17.75  PETRE174 PETRE PN 17,47
# 26   PETR4 PETROBRAS PN N2        PN       17.75   PETRE182 PETR PN 18,22
# 22   PETR4 PETROBRAS PN N2        PN       17.75   PETRE172 PETR PN 17,22
# 160  PETR4 PETROBRAS PN N2        PN       17.75   PETRE48 PETRE PN 16,97
# 27   PETR4 PETROBRAS PN N2        PN       17.75  PETRE184 PETRE PN 18,47
# 19   PETR4 PETROBRAS PN N2        PN       17.75   PETRE167 PETR PN 16,72
# 25   PETR4 PETROBRAS PN N2        PN       17.75  PETRF175 PETRE PN 17,55
# 28   PETR4 PETROBRAS PN N2        PN       17.75  PETRF180 PETRE PN 18,05
#
#     tipo_opcao data negociacao  valor opcao  strike data expiracao  volume  \
# 24          PN           07/05         0.77   17.72          18/05  5593.0
# 161         PN           07/05         0.65   17.97          18/05   275.0
# 23          PN           07/05         0.91   17.47          18/05   577.0
# 26          PN           07/05         0.53   18.22          18/05  7163.0
# 22          PN           07/05         1.06   17.22          18/05  4740.0
# 160         PN           07/05         1.26   16.97          18/05   615.0
# 27          PN           07/05         0.44   18.47          18/05     0.0
# 19          PN           07/05         1.45   16.72          18/05     0.0
# 25          PN           07/05         1.56   17.55          15/06     0.0
# 28          PN           07/05         1.30   18.05          15/06     0.0
#
#       lucro %    lucro aa
# 24   4.169014  138.335467
# 161  3.661972  121.510883
# 23   3.549296  117.772087
# 26   2.985915   99.078105
# 22   2.985915   99.078105
# 160  2.704225   89.731114
# 27   2.478873   82.253521
# 19   2.366197   78.514725
# 25   7.661972   71.708198
# 28   7.323944   68.544601

# %%
# get stock info
#petro = yf.Ticker('PETR4.SA')

ticker = yf.Ticker( papel_acao + '.SA')
# valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
hist = ticker.history(period='3mo')

ax = plt.gca()
hist.plot(y=['Close', 'High', 'Low', 'Close'], ax=ax)
hist.plot(secondary_y=True, y='Volume', ax=ax)
plt.show()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %%
from bovespa.indicator import indicator
# Out:
# Traceback (most recent call last):
#
#   File "/home/jairo/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-f3de67ccaf7d>", line 1, in <module>
#     from bovespa.indicator import indicator
#
#   File "/media/jairo/Dados/Jairo/Projetos/Bolsa/git/bovespa/bovespa/indicator.py", line 4
#     @property
#     ^
# IndentationError: expected an indented block
